# %% [markdown]
# <a href="https://colab.research.google.com/github/mascneto/IrisDataSet/blob/master/generos_musica_mais_feat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# Verifica se há GPUs disponíveis
physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))

# Se houver GPUs, imprime informações sobre a primeira GPU
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    print('GPU is available')
else:
    print("No GPU available")
# Out:
# Num GPUs Available:  0
# No GPU available

# %%
# No início do seu trabalho
import os
os.environ['KAGGLE_USERNAME'] = 'josmascarenhaslneto'
os.environ['KAGGLE_KEY'] = 'c46e15233b1ec4359983a179b866bc26'

# Faz seu trabalho com Kaggle aqui
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

"""# No final do trabalho
del os.environ['KAGGLE_USERNAME']
del os.environ['KAGGLE_KEY']"""
# Out:
# "# No final do trabalho\ndel os.environ['KAGGLE_USERNAME']\ndel os.environ['KAGGLE_KEY']"

# %%
api.dataset_download_files('andradaolteanu/gtzan-dataset-music-genre-classification',
                         path='/content',  # Este é o diretório padrão do Colab
                         unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/andradaolteanu/gtzan-dataset-music-genre-classification

# %%
# !ls /content/Data/genres_original/
# Out:
# blues  classical  country  disco  hiphop  jazz	metal  pop  reggae  rock

# %%
import os
import shutil # para copiar os arquivos
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import librosa.display

base_path = "/content/Data/genres_original"
output_dir = "selected_files"
os.makedirs(output_dir, exist_ok=True)
all_wav_files = []

for genre in os.listdir(base_path):
  genre_path = os.path.join(base_path, genre)
  # print(genre_path)

  if os.path.isdir(genre_path): # Verificar se é um diretório
    wav_files = [os.path.join(genre_path, f) for f in os.listdir(genre_path) if f.endswith(".wav")] # Filtrar apenas arquivos .wav
    wav_files.sort()
    all_wav_files.append(wav_files)


# Converter para uma matriz numpy
wav_matrix = np.array(all_wav_files, dtype=object)

# %%
wav_matrix.shape
# Out:
# (10, 100)

# %%
# Configuração do layout para os gráficos
num_files = len(wav_matrix[:,0])
cols = 2
rows = (num_files + 1) // cols

# Criar a figura para os subplots
fig, axs = plt.subplots(rows, cols, figsize=(15, 20))
axs = axs.ravel()  # Para acessar os subplots de forma linear

# Processar cada arquivo e plotar a FFT
for i, file_path in enumerate(wav_matrix[:,0]):
    try:
        # Obter o gênero a partir do caminho do arquivo
        genre = file_path.split('/')[-2]

        # Carregar o áudio
        y, sr = librosa.load(file_path, sr=None)

        # Calcular FFT
        fft = np.fft.fft(y)
        magnitude = np.abs(fft)
        frequency = np.fft.fftfreq(len(magnitude), 1 / sr)

        # Filtrar apenas frequências positivas
        pos_freqs = frequency[:len(frequency) // 2]
        pos_magnitude = magnitude[:len(magnitude) // 2]

        # Plotar a FFT
        axs[i].plot(pos_freqs, pos_magnitude)
        axs[i].set_title(f'FFT - {genre}')
        axs[i].set_xlabel('Frequência (Hz)')
        axs[i].set_ylabel('Magnitude')
        axs[i].grid()

    except Exception as e:
        print(f"Erro ao processar {file_path}: {e}")
        axs[i].set_title(f'Erro - {genre}')
        axs[i].axis('off')  # Desativa o subplot em caso de erro

# Ajustar espaçamento entre subplots
plt.tight_layout()

# %% [markdown]
# Sinais reais têm simetria conjugada, ou seja, as frequências negativas são um espelho das frequências positivas. Assim, não há perca de informação ao desconsiderá-las, tornando a análise mais simples.
# Matematicamente falando, seja $X[k]$ o resultado da FFT. \\
# Então $$X[-k] = \overline{X[k]}$$

# %%
regex = r"genres_original/([^/]+)/"
import re
# Aplicando a regex em cada elemento da matriz, convertendo para string
labels = [re.search(regex, str(path)).group(1) for path in wav_matrix] # Convert path to string using str(path)
labels = np.array(labels)
labels
# Out:
# array(['hiphop', 'metal', 'blues', 'jazz', 'country', 'classical', 'pop',
#        'reggae', 'disco', 'rock'], dtype='<U9')

# %%
def extract_audio_features(audio_path, fft_size=8000, n_mfcc=13, n_chroma=12):
    """
    Extracts MFCC, FFT, and chroma features from an audio file.

    Parameters:
    audio_path (str): Path to the audio file
    fft_size (int): Size of the FFT window
    n_mfcc (int): Number of MFCC coefficients to extract
    n_chroma (int): Number of chroma bins to extract

    Returns:
    tuple: (mfcc_features, fft_features, chroma_features, genre_label) or (None, None, None, None) if error occurs
    """
    try:
        # Carregar o arquivo de áudio
        y, sr = librosa.load(audio_path, sr=None)

        # Extrair MFCCs
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
        mfcc_features = np.mean(mfccs, axis=1)

        # Calcular FFT
        fft = np.fft.fft(y)
        magnitude = np.abs(fft[:len(fft)//2])

        # Padronizar o tamanho do FFT
        if len(magnitude) > fft_size:
            fft_features = magnitude[:fft_size]
        else:
            fft_features = np.pad(magnitude, (0, fft_size - len(magnitude)), mode='constant')

        # Extrair chroma features
        chroma = librosa.feature.chroma_stft(y=y, sr=sr, n_chroma=n_chroma)
        chroma_features = np.mean(chroma, axis=1)

        # Extrair o rótulo do gênero do caminho do arquivo
        genre_label = audio_path.split('/')[-2]

        return mfcc_features, fft_features, chroma_features, genre_label

    except Exception as e:
        print(f"Erro ao processar {audio_path}: {e}")
        return None, None, None, None

def process_audio_dataset(wav_matrix):
    """
    Process a matrix of audio files and extract features.

    Parameters:
    wav_matrix: Matrix containing paths to audio files organized by genre

    Returns:
    tuple: (mfcc_features, fft_features, chroma_features, labels)
    """
    all_mfcc_features = []
    all_fft_features = []
    all_chroma_features = []
    all_labels = []

    for genre_files in wav_matrix:
        for file_path in genre_files:
            mfcc_features, fft_features, chroma_features, genre_label = extract_audio_features(file_path)

            if mfcc_features is not None:
                all_mfcc_features.append(mfcc_features)
                all_fft_features.append(fft_features)
                all_chroma_features.append(chroma_features)
                all_labels.append(genre_label)

    return (
        np.array(all_mfcc_features),
        np.array(all_fft_features),
        np.array(all_chroma_features),
        np.array(all_labels)
    )

# %%
# Extrair features de todo o dataset
mfccs, ffts, cfs, labels = process_audio_dataset(wav_matrix)
# Out:
# <ipython-input-11-dd570bc79a14>:16: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path, sr=None)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Erro ao processar /content/Data/genres_original/jazz/jazz.00054.wav:

# %%
mfccs.shape, ffts.shape, cfs.shape, labels.shape
# Out:
# ((999, 13), (999, 8000), (999, 12), (999,))

# %%
features = np.hstack((mfccs, ffts, cfs))

# %%
features.shape
# Out:
# (999, 8025)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
unique, counts = np.unique(labels_encoded, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {0: 100, 1: 100, 2: 100, 3: 100, 4: 100, 5: 99, 6: 100, 7: 100, 8: 100, 9: 100}

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# %%
variances = np.var(features_scaled, axis=0)
print(f"Variância média: {np.mean(variances)}")
# Out:
# Variância média: 1.0

# %%
from sklearn.model_selection import train_test_split

X = features_scaled
y = labels_encoded

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)
X_train, X_val,  y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, random_state=42)

# %%
print(f"Tamanho do treino: {len(X_train)}")
print(f"Tamanho da validação: {len(X_val)}")
print(f"Tamanho do teste: {len(X_test)}")
# Out:
# Tamanho do treino: 721
# Tamanho da validação: 128
# Tamanho do teste: 150

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.95)
X_train_pca = pca.fit_transform(X_train)

# Agora, transformamos o conjunto de validação (e teste) com o PCA ajustado
X_val_pca = pca.transform(X_val)
X_test_pca = pca.transform(X_test)

# Verificação do resultado
print("Dimensão dos dados transformados:", X_train_pca.shape)
# Out:
# Dimensão dos dados transformados: (721, 385)

# %%
print("Variância explicada por componente:", pca.explained_variance_ratio_)
print("Variância total explicada:", pca.explained_variance_ratio_.sum())
# Out:
# Variância explicada por componente: [0.21689187 0.04942534 0.03062155 0.02060176 0.01818838 0.01660803
#  0.01369572 0.01207865 0.01125644 0.01057435 0.00990224 0.00872468
#  0.00861199 0.00795499 0.00770938 0.00758893 0.00717094 0.00667669
#  0.00627839 0.00625773 0.00607574 0.0057718  0.00561914 0.00521131
#  0.00492203 0.00481349 0.00450823 0.00443119 0.00437001 0.00419973
#  0.00410211 0.0040671  0.00397248 0.00378528 0.00370217 0.00362671
#  0.00356585 0.00348491 0.00344306 0.00333656 0.00328795 0.0031874
#  0.00316884 0.00312766 0.00309638 0.00304434 0.00300312 0.00292912
#  0.00291057 0.00287067 0.00284893 0.00280925 0.0027514  0.00273932
#  0.00272677 0.00271998 0.00267691 0.00264142 0.00263941 0.0025961
#  0.00258033 0.00253978 0.00253275 0.00251357 0.00248153 0.00246842
#  0.00243217 0.0024066  0.00236661 0.002344   0.00233592 0.00231465
#  0.00228957 0.00227786 0.00224535 0.00221621 0.0021861  0.00217953
#  0.00216275 0.00214656 0.00213366 0.00212559 0.00208912 0.00208446
#  0.00207672 0.00206676 0.00204548 0.00201277 0.00197309 0.00196804
#  0.00196253 0.00194754 0.00193463 0.00192996 0.00189511 0.0018802
#  0.00186999 0.00184813 0.0018388  0.00181957 0.00180616 0.00179196
#  0.00177844 0.00177224 0.00175083 0.00173675 0.00171959 0.00170225
#  0.00168684 0.00167027 0.00166523 0.00164503 0.0016369  0.00162138
#  0.00161339 0.0015925  0.00159078 0.00158175 0.0015714  0.00155968
#  0.00154014 0.00152849 0.00152435 0.00151981 0.00150331 0.00149206
#  0.00148122 0.0014646  0.00146116 0.00145046 0.0014315  0.00141848
#  0.00141508 0.00140209 0.0013943  0.00138546 0.00136666 0.00136265
#  0.00135224 0.00134956 0.00134698 0.00133643 0.00131138 0.00130518
#  0.00130371 0.00129611 0.00128662 0.00127738 0.00127144 0.00126347
#  0.0012558  0.00124931 0.0012424  0.00123717 0.00123089 0.00122169
#  0.0012163  0.00121071 0.00120197 0.00118604 0.00118104 0.00117758
#  0.00117446 0.00117092 0.00116237 0.00115612 0.00114896 0.00114308
#  0.00113343 0.00112927 0.00111381 0.00111021 0.0011049  0.00109683
#  0.00109268 0.00108843 0.0010855  0.00107773 0.00107271 0.00106345
#  0.00105431 0.00105161 0.00104249 0.00103303 0.00102768 0.00102629
#  0.00102068 0.00101606 0.00100929 0.00100157 0.00100109 0.00099332
#  0.00098975 0.00098223 0.00097616 0.00097252 0.00095964 0.00095744
#  0.0009558  0.00094813 0.00094402 0.0009395  0.00093533 0.00093278
#  0.00092277 0.00091658 0.00091368 0.0009131  0.00090407 0.00089778
#  0.00089353 0.00089089 0.00088491 0.00088455 0.00087519 0.00087375
#  0.00086893 0.00085882 0.0008551  0.00085268 0.00084808 0.0008453
#  0.00083904 0.00083663 0.00083206 0.00082748 0.00082336 0.0008198
#  0.00081669 0.00081178 0.00080757 0.00080108 0.00080024 0.00079356
#  0.00078803 0.00078722 0.00077953 0.00077776 0.00077299 0.00077148
#  0.00076537 0.000761   0.00075338 0.0007496  0.00074761 0.00074326
#  0.00073826 0.00073584 0.00073524 0.00072803 0.000721   0.00071954
#  0.00071553 0.00071317 0.00070445 0.00070173 0.00069833 0.00069408
#  0.00069233 0.00069065 0.00068875 0.00068202 0.00067437 0.00066983
#  0.00066768 0.00066329 0.00066201 0.00065863 0.00065588 0.00065487
#  0.00064697 0.000644   0.0006411  0.00063716 0.00063447 0.000631
#  0.00062814 0.0006254  0.00061954 0.00061697 0.00061562 0.00061375
#  0.00061141 0.00060633 0.00060453 0.0005986  0.00059699 0.00059462
#  0.00058813 0.00058793 0.00058161 0.00058035 0.00058019 0.00057536
#  0.00056997 0.00056761 0.00056686 0.00056278 0.00055944 0.00055385
#  0.00055109 0.00054897 0.00054843 0.00054565 0.00053938 0.00053781
#  0.00053675 0.00053381 0.00053192 0.00052933 0.00052671 0.00052578
#  0.00052546 0.00052069 0.00051554 0.00051286 0.00051161 0.00050644
#  0.00050561 0.00050413 0.00050156 0.00049871 0.00049625 0.00049366
#  0.00049265 0.00049113 0.00048713 0.00048628 0.00048346 0.00047818
#  0.00047744 0.00047406 0.00047266 0.00047036 0.00046806 0.00046585
#  0.00046272 0.00046142 0.00046091 0.00045683 0.00045544 0.0004516
#  0.00044935 0.00044635 0.00044357 0.00044169 0.00044104 0.00043976
#  0.00043412 0.0004335  0.00043113 0.00042917 0.0004274  0.00042617
#  0.00042518 0.00042377 0.0004216  0.000419   0.00041757 0.00041467
#  0.00041337 0.00041055 0.00040612 0.00040548 0.00040475 0.00040349
#  0.00040209 0.00039815 0.00039645 0.0003947  0.00039229 0.00039127
#  0.00039071 0.00038738 0.00038591 0.00038239 0.00038199 0.00037834
#  0.00037771 0.0003767  0.00037388 0.00037073 0.00036971 0.00036899
#  0.00036605]
# Variância total explicada: 0.9501180881915975

# %%
### Variância explicada acumulada em função do número de componentes
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_.cumsum(), marker='o')
plt.xlabel('Número de Componentes')
plt.ylabel('Variância Explicada Acumulada')
plt.title('Variância Explicada x Número de Componentes')
plt.grid()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# Gráfico 3D das primeiras 3 componentes principais
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_train_pca[:, 0], X_train_pca[:, 1], X_train_pca[:, 2], cmap='viridis', alpha=0.5)
ax.set_title('PCA - Primeiras 3 Componentes Principais')
ax.set_xlabel('Componente 1')
ax.set_ylabel('Componente 2')
ax.set_zlabel('Componente 3')
fig.colorbar(scatter, label='Classes')
plt.show()
# Out:
# <ipython-input-26-12829596d160>:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(X_train_pca[:, 0], X_train_pca[:, 1], X_train_pca[:, 2], cmap='viridis', alpha=0.5)

# %%
from sklearn.svm import SVC

# Instanciar o modelo SVM
svm_clf = SVC(kernel='rbf', random_state=42)

# Treinar o SVM
svm_clf.fit(X_train_pca, y_train)
# Out:
# SVC(random_state=42)

# %%
# Validação
X_val_pca  = pca.transform(X_val)
y_val_pred = svm_clf.predict(X_val_pca)

# %%
# Avaliar o modelo no conjunto de validação
from sklearn.metrics import classification_report, accuracy_score

print("Acurácia no conjunto de validação:", accuracy_score(y_val, y_val_pred))
print("Relatório de Classificação no conjunto de validação:")
print(classification_report(y_val, y_val_pred))
# Out:
# Acurácia no conjunto de validação: 0.484375
# Relatório de Classificação no conjunto de validação:
#               precision    recall  f1-score   support
#
#            0       0.86      0.50      0.63        12
#            1       0.69      0.82      0.75        11
#            2       0.28      0.62      0.38        13
#            3       0.45      0.42      0.43        12
#            4       0.67      0.14      0.24        14
#            5       0.69      0.61      0.65        18
#            6       0.41      0.58      0.48        12
#            7       0.38      0.30      0.33        10
#            8       0.35      0.78      0.48         9
#            9       1.00      0.24      0.38        17
#
#     accuracy                           0.48       128
#    macro avg       0.58      0.50      0.48       128
# weighted avg       0.61      0.48      0.48       128

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint

# Parâmetros a serem otimizados
param_dist = {
    'C': uniform(0.1, 10),  # Parâmetro de regularização
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],  # Tipos de kernel
    'gamma': ['scale', 'auto'],  # Tipo de gama
    'degree': randint(1, 5)  # Grau do polinômio (para kernel 'poly')
}

"""
C: controla a penalidade para erros de classificação.
Valores mais altos de C tentam reduzir os erros, mas podem levar a overffiting

gamma: Controla o quanto a influênca de um único ponto de treino se estende.
Valores mais baixos significam maior alcance
"""

# Configuração do RandomizedSearchCV
random_search = RandomizedSearchCV(
    svm_clf,
    param_distributions=param_dist,
    n_iter=100,
    cv=5,
    verbose=2,
    n_jobs=-1,
    random_state=42,
    scoring='accuracy'
)

# %%
random_search.fit(X_train_pca, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-48b7d1c3a526> in <cell line: 1>()
# ----> 1 random_search.fit(X_train_pca, y_train)
#
# NameError: name 'random_search' is not defined

# %%
best_model = grid_search.best_estimator_ # melhor modelo encontrado pelo GridSearch

y_val_pred = best_model.predict(X_val_pca)

print("Acurácia no conjunto de validação:", accuracy_score(y_val, y_val_pred))
# print("Relatório de Classificação no conjunto de validação:")
print(classification_report(y_val, y_val_pred))

y_test_pred = best_model.predict(X_test_pca)
print("Acurácia no conjunto de teste:", accuracy_score(y_test, y_test_pred))
# Out:
# Acurácia no conjunto de validação: 0.5703125
# Relatório de Classificação no conjunto de validação:
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62        18
#            1       0.93      0.93      0.93        14
#            2       0.25      0.27      0.26        11
#            3       0.45      0.42      0.43        12
#            4       0.56      0.53      0.55        17
#            5       0.89      0.67      0.76        12
#            6       0.50      0.58      0.54        12
#            7       0.60      0.46      0.52        13
#            8       0.58      0.70      0.64        10
#            9       0.33      0.33      0.33         9
#
#     accuracy                           0.57       128
#    macro avg       0.57      0.56      0.56       128
# weighted avg       0.58      0.57      0.57       128

# %% [markdown]
# Após o ajuste dos hiperparâmetros, a acurácia aumentou cerca de 7%

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_clf = RandomForestClassifier(n_estimators=100, random_state=42)
rf_clf.fit(X_train_pca, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_val_pred = rf_clf.predict(X_val_pca)
val_accuracy = accuracy_score(y_val, y_val_pred)
val_accuracy
# Out:
# 0.4765625

# %%
y_test_pred = rf_clf.predict(X_test_pca)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_accuracy
# Out:
# 0.47333333333333333

# %%
# Relatório completo de métricas
print("\nRelatório de Classificação:")
print(classification_report(y_test, y_test_pred))
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       0.83      0.33      0.48        15
#            1       0.94      0.89      0.91        18
#            2       0.53      0.41      0.46        22
#            3       0.44      0.42      0.43        19
#            4       0.75      0.23      0.35        13
#            5       0.43      0.80      0.56        15
#            6       0.20      0.30      0.24        10
#            7       0.50      0.10      0.17        10
#            8       0.35      0.64      0.45        14
#            9       0.29      0.36      0.32        14
#
#     accuracy                           0.47       150
#    macro avg       0.53      0.45      0.44       150
# weighted avg       0.54      0.47      0.47       150

# %%
# Definir os hiperparâmetros para busca
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

# %%
# Criar o modelo base
rf_clf = RandomForestClassifier(random_state=42)

# Configurar o GridSearchCV
grid_search = GridSearchCV(
    estimator=rf_clf,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5,  # Validação cruzada com 5 folds
    verbose=2,
    n_jobs=-1
)

# %%
grid_search.fit(X_train_pca, y_train)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy', verbose=2)

# %%
best_rf = grid_search.best_estimator_
y_val_pred = best_rf.predict(X_val_pca)
val_accuracy = accuracy_score(y_val, y_val_pred)
val_accuracy

y_test_pred = best_rf.predict(X_test_pca)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_accuracy
# Out:
# 0.46

# %%
print(f"Relação acurácia de teste e validação:\nValidação: {val_accuracy}\nTeste: {test_accuracy} ")
# Out:
# Relação acurácia de teste e validação:
# Validação: 0.4765625
# Teste: 0.46

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb_clf = GradientBoostingClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42
)

# %%
gb_clf.fit(X_train_pca, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_val_pred = gb_clf.predict(X_val_pca)
val_accuracy = accuracy_score(y_val, y_val_pred)
print(f"Acurácia da predição de validação: {val_accuracy}")
# Out:
# Acurácia da predição de validação: 0.453125

# %%
y_test_pred = gb_clf.predict(X_test_pca)
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"Acurácia da predição de teste: {test_accuracy}")
# Out:
# Acurácia da predição de teste: 0.4533333333333333

# %%
# Configurar o modelo
gb_clf = GradientBoostingClassifier(random_state=42)

# Definir o grid de hiperparâmetros
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 4, 5],
    'subsample': [0.8, 1.0],
    'min_samples_split': [2, 5, 10]
}

# Configurar o Grid Search
grid_search = GridSearchCV(estimator=gb_clf, param_grid=param_grid, cv=3, scoring='accuracy', verbose=2, n_jobs=-1)

# %%
# Ajustar o Grid Search aos dados de treino
grid_search.fit(X_train_pca, y_train)
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
